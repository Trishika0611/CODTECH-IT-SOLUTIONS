# %% [markdown]
# <a href="https://colab.research.google.com/github/Trishika0611/CODTECH-IT-SOLUTIONS/blob/main/TASK_3_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 3: CNN for Image Classification
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)
datagen.fit(X_train)

model = models.Sequential([
    layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

lr_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                 patience=3,
                                 factor=0.5,
                                 min_lr=1e-5,
                                 verbose=1)
early_stop = EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True)

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    epochs=25,
    validation_data=(X_test, y_test),
    callbacks=[lr_reduction, early_stop]
)

test_loss, test_acc = model.evaluate(X_test, y_test)
print("\nTest Accuracy: {:.2f}%".format(test_acc * 100))

model.save("cnn_cifar10_model.h5")
# Out:
# Epoch 1/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 59ms/step - accuracy: 0.3299 - loss: 2.1276 - val_accuracy: 0.5077 - val_loss: 1.4271 - learning_rate: 0.0010
# Epoch 2/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.5383 - loss: 1.2907 - val_accuracy: 0.5861 - val_loss: 1.1985 - learning_rate: 0.0010
# Epoch 3/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.6183 - loss: 1.0686 - val_accuracy: 0.6240 - val_loss: 1.1267 - learning_rate: 0.0010
# Epoch 4/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.6661 - loss: 0.9516 - val_accuracy: 0.6977 - val_loss: 0.9099 - learning_rate: 0.0010
# Epoch 5/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.6980 - loss: 0.8721 - val_accuracy: 0.7276 - val_loss: 0.7970 - learning_rate: 0.0010
# Epoch 6/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.7160 - loss: 0.8150 - val_accuracy: 0.6355 - val_loss: 1.1939 - learning_rate: 0.0010
# Epoch 7/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.7283 - loss: 0.7804 - val_accuracy: 0.7650 - val_loss: 0.6882 - learning_rate: 0.0010
# Epoch 8/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7526 - loss: 0.7256 - val_accuracy: 0.7298 - val_loss: 0.8051 - learning_rate: 0.0010
# Epoch 9/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7643 - loss: 0.6906 - val_accuracy: 0.8050 - val_loss: 0.5746 - learning_rate: 0.0010
# Epoch 10/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.7666 - loss: 0.6697 - val_accuracy: 0.8133 - val_loss: 0.5463 - learning_rate: 0.0010
# Epoch 11/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.7738 - loss: 0.6563 - val_accuracy: 0.8121 - val_loss: 0.5501 - learning_rate: 0.0010
# Epoch 12/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.7848 - loss: 0.6230 - val_accuracy: 0.8030 - val_loss: 0.5921 - learning_rate: 0.0010
# Epoch 13/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7931 - loss: 0.6020
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7931 - loss: 0.6020 - val_accuracy: 0.7567 - val_loss: 0.7551 - learning_rate: 0.0010
# Epoch 14/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8100 - loss: 0.5514 - val_accuracy: 0.8286 - val_loss: 0.5061 - learning_rate: 5.0000e-04
# Epoch 15/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8126 - loss: 0.5444 - val_accuracy: 0.8288 - val_loss: 0.5073 - learning_rate: 5.0000e-04
# Epoch 16/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8208 - loss: 0.5211 - val_accuracy: 0.8325 - val_loss: 0.5026 - learning_rate: 5.0000e-04
# Epoch 17/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.8214 - loss: 0.5202 - val_accuracy: 0.8515 - val_loss: 0.4384 - learning_rate: 5.0000e-04
# Epoch 18/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8236 - loss: 0.5139 - val_accuracy: 0.8505 - val_loss: 0.4396 - learning_rate: 5.0000e-04
# Epoch 19/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8301 - loss: 0.5009 - val_accuracy: 0.8175 - val_loss: 0.5650 - learning_rate: 5.0000e-04
# Epoch 20/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8308 - loss: 0.4947
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8308 - loss: 0.4947 - val_accuracy: 0.8464 - val_loss: 0.4630 - learning_rate: 5.0000e-04
# Epoch 21/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8401 - loss: 0.4698 - val_accuracy: 0.8558 - val_loss: 0.4294 - learning_rate: 2.5000e-04
# Epoch 22/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8387 - loss: 0.4609 - val_accuracy: 0.8493 - val_loss: 0.4573 - learning_rate: 2.5000e-04
# Epoch 23/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.8432 - loss: 0.4541 - val_accuracy: 0.8633 - val_loss: 0.4042 - learning_rate: 2.5000e-04
# Epoch 24/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8437 - loss: 0.4573 - val_accuracy: 0.8543 - val_loss: 0.4407 - learning_rate: 2.5000e-04
# Epoch 25/25
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8473 - loss: 0.4386 - val_accuracy: 0.8546 - val_loss: 0.4441 - learning_rate: 2.5000e-04
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8666 - loss: 0.4012
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 86.33%

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot training accuracy and loss
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Show some sample predictions
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

plt.figure(figsize=(12,6))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(X_test[i])
    plt.title(f"True: {class_names[y_test[i][0]]}\nPred: {class_names[y_pred_classes[i]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
